# %% [markdown]
# # Deep Q-learning
#
# The goal of a DQN agent is to maximize the future discounted return at each timestep $t$, namely
#
# $$ R_t = \sum_{t'=t}^T \gamma^{t'-t}r_{t'} $$
#
# assuming the environment episode ends at timestep $T$. The optimal action-value function $Q^*(s; a)$ defines the maximum discounted return achievable, i.e. when following an optimal policy $\pi^*$. This optimal action-value function satisfies a recursive relationship called the Bellman optimality Eq. $(1)$, where $\mathcal{S}$ is the distribution over next states $s'$ given a state $s_t$ and action $a_t$:
# $$
# Q^*(s,a) := \max_{\pi}\mathbb{E}_{\pi} \Big[R_t ~\big|~ s_t=s, ~a_t=a\Big] \implies Q^*(s,a) = \mathbb{E}_{s'\sim \mathcal{S}}\Big[r + \gamma \max_{a'} Q^*(s',a') ~\big|~ s, a\Big] \qquad (1)
# $$
#
# Generally, we can estimate this optimal Q-function by updating the Q-value function in an iterative fashion as
# $$ Q_{i+1}(s,a) = \mathbb{E}_{s'\sim \mathcal{S}}\Big[r + \gamma \max_{a'} Q_i(s',a') ~\big|~ s, a\Big] \qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad (2)$$
# which ultimately converges to $Q^*$ as the iterations $i$ goes to infinity. In DQN we use a function approximator to represent the Q-value function. Therefore, instead of assigning values as in Eq. $(2)$ we solve a regression problem, as detailed below in Section 2. Also, instead of trying to impose Eq. $(2)$ in all $(s,a)$ pairs, they are sampled from a *replay buffer* that at every iteration received new pairs obtained by executing in the environment the actions given by an "epsilon-greedy" sampling proceedure also described in Section 2.
#
# In this assignemnt you will be asked to implement three parts:
# - Define a Neural Network class that will be used as the Q-function approximator.
# - Implement the epsilon-greedy sampling proceedure.
# - Implement the Q-learning loss function.
#
# Then you will be able to test your algorithm in two environments: a simple grid-world and a more complex Atari game called Pong.

# %%
# import helpers, gym environments, and other needed dependencies
from collections import deque
import time
import numpy as np
import pickle
import os.path as osp
import click
import gym

from simpledqn.replay_buffer import ReplayBuffer
import logger
from simpledqn.wrappers import NoopResetEnv, EpisodicLifeEnv
from simpledqn import gridworld_env
from simpledqn.main import assert_allclose, preprocess_obs_gridworld, preprocess_obs_ram, LinearSchedule

nprs = np.random.RandomState
rng = nprs(42)

# %% [markdown]
# ## 1. Construcing a Neural Network
# Build a NN with **3 linear layers** (take 256 for all hidden sizes) and **relu** non-linearities at each layer output but the last.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.autograd as autograd

class NN_linear(nn.Module):
    def __init__(self, obs_size, act_size):
        super(NN_linear, self).__init__()
        self.Linear = nn.Linear(obs_size, act_size)

    def forward(self, obs):
        out = self.Linear(obs)
        return out
    
class NN(nn.Module):
    def __init__(self, obs_size, act_size):
        super(NN, self).__init__()
        "*** YOUR CODE HERE ***"
        
    def forward(self, obs):
        "*** YOUR CODE HERE ***"
        out = None
        return out

# %% [markdown]
# ## 2. Training the Q-function approximators
#
# The function $Q(s,a; \theta)$ is trained to approximate $Q^*(s,a)$ over time using a loss function defined as:
# $$ \mathbb{E}_{(s,a,s')\sim\mathcal{D}}\big[(y-Q(s,a;\theta))^2\big], \qquad\text{ where }\quad y= \begin{cases}
# r+\gamma\max_{a'}Q(s',a';\theta') \qquad\text{ if non-terminal transition}\\
# r \qquad\qquad\qquad\qquad\qquad\text{ for terminal transition}
# \end{cases} \qquad\qquad (3)
# $$
# where the network $Q(s; a; \theta')$ is called the target network, and its parameters $\theta'$ are updated (i.e. set to the current value of $\theta$) at a specific interval.
# DQN is inherently off-policy, which means that we can update the agent towards the goal behavior through using data that is sampled from arbitrary behavior. Therefore, all sampled $(s; a; s'; r)$ tuples are stored in a replay buffer $\mathcal{D}$.
# The approximator $Q(s,a; \theta)$ is updated by minimizing the loss described in Eq. $(3)$. In between updates, we add new tuples $(s,a,s',r)$ to the replay buffer by taking actions in the environment with and **epsilon greedy** proceedure:
#
# **for** $t$ from 1 to T do:
# * with probability $\epsilon$ select random action $a_t$, otherwise select $a_t = \max_a Q(s, a; \theta)$
# * execute action $a_t$ in environment and observe reward $r_t$, next state $s_{t+1}$ and episode termination signal $d_t$
# * store transition $(s_t, a_t, r_t, s_{t+1}, d_t)$ in $\mathcal{D}$.
#
# **end**

# %% [markdown]
# *In the next DQN class do the following:*
# - complete the **epsilon greedy** action sampling
# - write the full `compute_q_learning_loss` function

# %%
class DQN(object):
    def __init__(self, env, obs_dim, act_dim, obs_preprocessor, replay_buffer, NN, 
                 opt_batch_size, discount, initial_step, max_steps, learning_start_itr, target_q_update_freq,
                 train_q_freq, log_freq, final_eps, initial_eps, fraction_eps, render):
        self._env = env
        self._obs_dim = obs_dim
        self._act_dim = act_dim
        self._obs_preprocessor = obs_preprocessor
        self._replay_buffer = replay_buffer
        self._initial_step = initial_step
        self._max_steps = max_steps
        self._target_q_update_freq = target_q_update_freq
        self._learning_start_itr = learning_start_itr
        self._train_q_freq = train_q_freq
        self._log_freq = log_freq
        self._opt_batch_size = opt_batch_size
        self._discount = discount
        self._render = render

        self._q = NN(self._obs_dim, self._act_dim)  # Q function which params are optimized
        self._qt = NN(self._obs_dim, self._act_dim)  # target Q copying the params in Q after several updates
        self._qt.requires_grad = False
        
        self.optimizer = optim.Adam(self._q.parameters(), lr=0.0001)

        self.exploration = LinearSchedule(  # gives value of eps across iterations
            schedule_timesteps=int(fraction_eps * max_steps),
            initial_p=initial_eps,
            final_p=final_eps)

    def eps_greedy(self, obs, epsilon):
        # Check Q function, do argmax.
        rnd = rng.rand()
        if rnd > epsilon:
            obs = self._obs_preprocessor(obs)
            "*** YOUR CODE HERE ***"
            # compute q_values of obs
            q_values = np.ones(self._act_dim)
            # return the greedy action
            return 0
        else:
            return rng.randint(0, self._act_dim)

    def compute_q_learning_loss(self, l_obs, l_act, l_rew, l_next_obs, l_done):
        """
        :param l_obs: A np.array holding a list of observations. Should be of shape N * |S|.
        :param l_act: A np.array variable holding a list of actions. Should be of shape N.
        :param l_rew: A np.array variable holding a list of rewards. Should be of shape N.
        :param l_next_obs: A np.array variable holding a list of observations at the next time step. Should be of
        shape N * |S|.
        :param l_done: A np.array variable holding a list of binary values (indicating whether episode ended after this
        time step). Should be of shape N.
        :return: A PyTorch Variable holding a scalar loss.
        """

        "*** YOUR CODE HERE ***"
        # wrap the observations into Variables
        l_next_obs_var = autograd.Variable(torch.Tensor(l_next_obs), requires_grad=False)
        l_obs_var = autograd.Variable(torch.Tensor(l_obs), requires_grad=False)

        # compute Q values of the next_obs based on the target Q network self._qt, and convert back to numpy
        qt_next = 0
        
        # compute the target for the MSELoss (you can do it entirely in numpy). Use self._discount
        target = 0

        # wrap into a Variable
        target = autograd.Variable(torch.Tensor(target), requires_grad=False)
        # compute Q values aelf._q of current obs and select the one corresponding to the action that was taken
        q_sel = autograd.Variable(torch.Tensor(0), requires_grad=False)

        # form the MSELOss and compute it
        loss = autograd.Variable(torch.Tensor([0]), requires_grad=False)
        return loss


    def train_q(self, l_obs, l_act, l_rew, l_next_obs, l_done):
        """Update Q-value function by sampling from the replay buffer."""
        self._q.zero_grad()
        
        l_obs = self._obs_preprocessor(l_obs)
        l_next_obs = self._obs_preprocessor(l_next_obs)
        
        loss = self.compute_q_learning_loss(
            l_obs, l_act, l_rew, l_next_obs, l_done)
        
        loss.backward()
        self.optimizer.step()
        
        return loss.data

    def _update_target_q(self):
        """Update the target Q-value function by copying the current Q-value function weights."""
        q_params_dict = dict(self._q.named_parameters())
        self._qt.load_state_dict(q_params_dict)

    def train(self):
        obs = self._env.reset()

        episode_rewards = []
        n_episodes = 0
        l_episode_return = deque([], maxlen=10)
        l_discounted_episode_return = deque([], maxlen=10)
        l_tq_squared_error = deque(maxlen=50)
        log_itr = -1
        for itr in range(self._initial_step, self._max_steps):
            act = self.eps_greedy(obs[np.newaxis, :],
                                  self.exploration.value(itr))
            next_obs, rew, done, _ = self._env.step(act)
            if self._render:
                self._env.render()
            self._replay_buffer.add(obs, act, rew, next_obs, float(done))

            episode_rewards.append(rew)

            if done:
                obs = self._env.reset()
                episode_return = np.sum(episode_rewards)
                discounted_episode_return = np.sum(
                    episode_rewards * self._discount ** np.arange(len(episode_rewards)))
                l_episode_return.append(episode_return)
                l_discounted_episode_return.append(discounted_episode_return)
                episode_rewards = []
                n_episodes += 1
            else:
                obs = next_obs

            if itr % self._target_q_update_freq == 0 and itr > self._learning_start_itr:
                self._update_target_q()

            if itr % self._train_q_freq == 0 and itr > self._learning_start_itr:
                # Sample from replay buffer.
                l_obs, l_act, l_rew, l_obs_prime, l_done = self._replay_buffer.sample(
                    self._opt_batch_size)
                # Train Q value function with sampled data.
                td_squared_error = self.train_q(
                    l_obs, l_act, l_rew, l_obs_prime, l_done)
                l_tq_squared_error.append(td_squared_error)

            if (itr + 1) % self._log_freq == 0 and len(l_episode_return) > 5:
                log_itr += 1
                logger.logkv('Iteration', log_itr)
                logger.logkv('Steps', itr)
                logger.logkv('Epsilon', self.exploration.value(itr))
                logger.logkv('Episodes', n_episodes)
                logger.logkv('AverageReturn', np.mean(l_episode_return))
                logger.logkv('AverageDiscountedReturn',
                             np.mean(l_discounted_episode_return))
                logger.logkv('TDError^2', np.mean(l_tq_squared_error))
                logger.dumpkvs()
#                 self._q.dump(logger.get_dir() + '/weights.pkl')

    def test(self, epsilon):
        try:
            self._q.set_params(self._q.load(logger.get_dir() + '/weights.pkl'))
        except Exception as e:
            print(e)
        obs = self._env.reset()
        while True:
            act = self.eps_greedy(obs[np.newaxis, :], epsilon)
            obs_prime, rew, done, _ = self._env.step(act)
            self._env.render()
            if done:
                obs = self._env.reset()
                print('Done!')
                time.sleep(1)
            else:
                obs = obs_prime

# %% [markdown]
# ## 3. Test the algorithm on grid world
# Now let's train a simple GridWorld to test out our algorithm!

# %%
env = gym.make('GridWorld-v0')
test_dir = "data/local/dqn_gridworld_test"
log_dir = "data/local/dqn_gridworld2"
logger.session(log_dir).__enter__()
env.seed(42)

# Initialize the replay buffer that we will use.
replay_buffer = ReplayBuffer(max_size=10000)

# Initialize DQN training procedure.
dqn_gridworld = DQN(
    env=env,
    obs_dim=env.observation_space.n,
    act_dim=env.action_space.n,
    NN=NN_linear,
    obs_preprocessor=preprocess_obs_gridworld,
    replay_buffer=replay_buffer,
    opt_batch_size=64,
    # DQN gamma parameter
    discount=0.99,
    # Training procedure length
    initial_step=0,
    max_steps=100000,
    learning_start_itr=1000,
    # Frequency of copying the actual Q to the target Q
    target_q_update_freq=100,
    # Frequency of updating the Q-value function
    train_q_freq=4,
    # Exploration parameters
    initial_eps=1.0,
    final_eps=0.05,
    fraction_eps=0.1,
    # Logging
    log_freq=1000,
    render=False,
)

from simpledqn.main import test_loss
test_loss(dqn_gridworld, test_dir)
# Out:
# [2018-04-12 18:09:00,587] Making new env: GridWorld-v0
# [ 2.21811724]
# Test for compute_q_learning_loss passed!

# %% [markdown]
# If you passed the previous test, let's train the full policy!

# %%
dqn_gridworld.train()
# Out:
# --------------------------------------
# | Iteration               | 0        |
# | Steps                   | 999      |
# | Epsilon                 | 0.90509  |
# | Episodes                | 63       |
# | AverageReturn           | 0        |
# | AverageDiscountedReturn | 0        |
# | TDError^2               | nan      |
# --------------------------------------
# /Users/florensacc/anaconda2/envs/deeprlbootcamp/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/florensacc/anaconda2/envs/deeprlbootcamp/lib/python3.5/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --------------------------------------
# | Iteration               | 1        |
# | Steps                   | 1999     |
# | Epsilon                 | 0.8101   |
# | Episodes                | 124      |
# | AverageReturn           | 0.3      |
# | AverageDiscountedReturn | 0.26066  |
# | TDError^2               | 0.080576 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 2        |
# | Steps                   | 2999     |
# | Epsilon                 | 0.7151   |
# | Episodes                | 195      |
# | AverageReturn           | 0.2      |
# | AverageDiscountedReturn | 0.18456  |
# | TDError^2               | 0.063006 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 3        |
# | Steps                   | 3999     |
# | Epsilon                 | 0.6201   |
# | Episodes                | 277      |
# | AverageReturn           | 0.1      |
# | AverageDiscountedReturn | 0.089534 |
# | TDError^2               | 0.050756 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 4        |
# | Steps                   | 4999     |
# | Epsilon                 | 0.5251   |
# | Episodes                | 345      |
# | AverageReturn           | 0.3      |
# | AverageDiscountedReturn | 0.24743  |
# | TDError^2               | 0.039843 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 5        |
# | Steps                   | 5999     |
# | Epsilon                 | 0.4301   |
# | Episodes                | 417      |
# | AverageReturn           | 0.1      |
# | AverageDiscountedReturn | 0.090438 |
# | TDError^2               | 0.033283 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 6        |
# | Steps                   | 6999     |
# | Epsilon                 | 0.3351   |
# | Episodes                | 471      |
# | AverageReturn           | 0.4      |
# | AverageDiscountedReturn | 0.3352   |
# | TDError^2               | 0.030623 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 7        |
# | Steps                   | 7999     |
# | Epsilon                 | 0.24009  |
# | Episodes                | 516      |
# | AverageReturn           | 0.6      |
# | AverageDiscountedReturn | 0.49148  |
# | TDError^2               | 0.024071 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 8        |
# | Steps                   | 8999     |
# | Epsilon                 | 0.14509  |
# | Episodes                | 556      |
# | AverageReturn           | 0.3      |
# | AverageDiscountedReturn | 0.22594  |
# | TDError^2               | 0.01997  |
# --------------------------------------
# --------------------------------------
# | Iteration               | 9        |
# | Steps                   | 9999     |
# | Epsilon                 | 0.050095 |
# | Episodes                | 596      |
# | AverageReturn           | 0.7      |
# | AverageDiscountedReturn | 0.54859  |
# | TDError^2               | 0.018474 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 10       |
# | Steps                   | 10999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 636      |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.78722  |
# | TDError^2               | 0.017138 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 11       |
# | Steps                   | 11999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 787      |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.95099  |
# | TDError^2               | 0.017824 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 12       |
# | Steps                   | 12999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 934      |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.8521   |
# | TDError^2               | 0.016669 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 13       |
# | Steps                   | 13999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1086     |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.85589  |
# | TDError^2               | 0.016457 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 14       |
# | Steps                   | 14999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1246     |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.85494  |
# | TDError^2               | 0.016086 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 15       |
# | Steps                   | 15999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1408     |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.85589  |
# | TDError^2               | 0.014195 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 16       |
# | Steps                   | 16999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1567     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.95004  |
# | TDError^2               | 0.015331 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 17       |
# | Steps                   | 17999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1727     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.95099  |
# | TDError^2               | 0.01545  |
# --------------------------------------
# --------------------------------------
# | Iteration               | 18       |
# | Steps                   | 18999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 1889     |
# | AverageReturn           | 0.9      |
# | AverageDiscountedReturn | 0.85123  |
# | TDError^2               | 0.013319 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 19       |
# | Steps                   | 19999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 2048     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.9491   |
# | TDError^2               | 0.01098  |
# --------------------------------------
# --------------------------------------
# | Iteration               | 20       |
# | Steps                   | 20999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 2208     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.95099  |
# | TDError^2               | 0.008623 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 21        |
# | Steps                   | 21999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 2368      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95004   |
# | TDError^2               | 0.0081578 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 22        |
# | Steps                   | 22999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 2524      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94815   |
# | TDError^2               | 0.0087976 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 23        |
# | Steps                   | 23999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 2683      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0074456 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 24        |
# | Steps                   | 24999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 2845      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0077018 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 25        |
# | Steps                   | 25999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3008      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94909   |
# | TDError^2               | 0.0071112 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 26        |
# | Steps                   | 26999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3169      |
# | AverageReturn           | 0.9       |
# | AverageDiscountedReturn | 0.85494   |
# | TDError^2               | 0.0075006 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 27        |
# | Steps                   | 27999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3330      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0085055 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 28        |
# | Steps                   | 28999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3491      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0055299 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 29        |
# | Steps                   | 29999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3649      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0050842 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 30        |
# | Steps                   | 30999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 3808      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0057086 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 31       |
# | Steps                   | 31999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 3967     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.94724  |
# | TDError^2               | 0.005811 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 32        |
# | Steps                   | 32999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4128      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94724   |
# | TDError^2               | 0.0049162 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 33        |
# | Steps                   | 33999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4286      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94346   |
# | TDError^2               | 0.0045813 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 34        |
# | Steps                   | 34999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4441      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94253   |
# | TDError^2               | 0.0044327 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 35        |
# | Steps                   | 35999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4602      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0044363 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 36        |
# | Steps                   | 36999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4759      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0031916 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 37        |
# | Steps                   | 37999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 4920      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94535   |
# | TDError^2               | 0.0038843 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 38        |
# | Steps                   | 38999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5080      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94815   |
# | TDError^2               | 0.0027002 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 39        |
# | Steps                   | 39999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5243      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94724   |
# | TDError^2               | 0.0028699 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 40        |
# | Steps                   | 40999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5403      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0030269 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 41        |
# | Steps                   | 41999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5562      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.93974   |
# | TDError^2               | 0.0027193 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 42        |
# | Steps                   | 42999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5642      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0023117 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 43        |
# | Steps                   | 43999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 5713      |
# | AverageReturn           | 0.7       |
# | AverageDiscountedReturn | 0.57582   |
# | TDError^2               | 0.0025804 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 44       |
# | Steps                   | 44999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 5838     |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.95004  |
# | TDError^2               | 0.00434  |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 45        |
# | Steps                   | 45999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6000      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94627   |
# | TDError^2               | 0.0031205 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 46        |
# | Steps                   | 46999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6156      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94095   |
# | TDError^2               | 0.0030407 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 47        |
# | Steps                   | 47999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6314      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0021958 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 48        |
# | Steps                   | 48999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6478      |
# | AverageReturn           | 0.9       |
# | AverageDiscountedReturn | 0.85305   |
# | TDError^2               | 0.0034721 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 49        |
# | Steps                   | 49999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6583      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94815   |
# | TDError^2               | 0.0046768 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 50        |
# | Steps                   | 50999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6737      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94817   |
# | TDError^2               | 0.0048396 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 51        |
# | Steps                   | 51999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 6898      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95004   |
# | TDError^2               | 0.0039258 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 52        |
# | Steps                   | 52999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7057      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94724   |
# | TDError^2               | 0.0013239 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 53        |
# | Steps                   | 53999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7195      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0014976 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 54        |
# | Steps                   | 54999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7354      |
# | AverageReturn           | 0.9       |
# | AverageDiscountedReturn | 0.85589   |
# | TDError^2               | 0.0012513 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 55        |
# | Steps                   | 55999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7516      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0010351 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 56        |
# | Steps                   | 56999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7608      |
# | AverageReturn           | 0.5       |
# | AverageDiscountedReturn | 0.41136   |
# | TDError^2               | 0.0012282 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 57        |
# | Steps                   | 57999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7727      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94815   |
# | TDError^2               | 0.0011632 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 58        |
# | Steps                   | 58999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 7890      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0020184 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 59         |
# | Steps                   | 59999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 8047       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94353    |
# | TDError^2               | 0.00076731 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 60         |
# | Steps                   | 60999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 8208       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.95099    |
# | TDError^2               | 0.00039195 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 61        |
# | Steps                   | 61999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 8369      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95004   |
# | TDError^2               | 0.0020498 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 62        |
# | Steps                   | 62999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 8533      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0020089 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 63         |
# | Steps                   | 63999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 8696       |
# | AverageReturn           | 0.9        |
# | AverageDiscountedReturn | 0.85399    |
# | TDError^2               | 0.00012025 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 64        |
# | Steps                   | 64999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 8857      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0014811 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 65        |
# | Steps                   | 65999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 9015      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94815   |
# | TDError^2               | 0.0001161 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 66         |
# | Steps                   | 66999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 9173       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.95004    |
# | TDError^2               | 0.00067767 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 67         |
# | Steps                   | 67999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 9333       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94721    |
# | TDError^2               | 0.00028208 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 68         |
# | Steps                   | 68999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 9489       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94627    |
# | TDError^2               | 0.00038364 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 69         |
# | Steps                   | 69999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 9650       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94721    |
# | TDError^2               | 0.00024526 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 70         |
# | Steps                   | 70999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 9808       |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.9491     |
# | TDError^2               | 0.00035136 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 71        |
# | Steps                   | 71999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 9949      |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.93966   |
# | TDError^2               | 0.0013128 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 72         |
# | Steps                   | 72999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 10096      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94724    |
# | TDError^2               | 0.00048382 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 73         |
# | Steps                   | 73999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 10254      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.9491     |
# | TDError^2               | 0.00045586 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 74         |
# | Steps                   | 74999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 10372      |
# | AverageReturn           | 0.4        |
# | AverageDiscountedReturn | 0.34969    |
# | TDError^2               | 0.00074418 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 75        |
# | Steps                   | 75999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 10524     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0011017 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 76        |
# | Steps                   | 76999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 10685     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95004   |
# | TDError^2               | 0.0010889 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 77         |
# | Steps                   | 77999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 10841      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94815    |
# | TDError^2               | 0.00083205 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 78        |
# | Steps                   | 78999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 10998     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94438   |
# | TDError^2               | 0.0010534 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 79        |
# | Steps                   | 79999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 11160     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0011193 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 80        |
# | Steps                   | 80999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 11317     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0016365 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 81        |
# | Steps                   | 81999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 11474     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0016671 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 82         |
# | Steps                   | 82999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 11573      |
# | AverageReturn           | 0.6        |
# | AverageDiscountedReturn | 0.46569    |
# | TDError^2               | 0.00095854 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 83         |
# | Steps                   | 83999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 11715      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.95004    |
# | TDError^2               | 0.00094692 |
# ----------------------------------------
# --------------------------------------
# | Iteration               | 84       |
# | Steps                   | 84999    |
# | Epsilon                 | 0.05     |
# | Episodes                | 11874    |
# | AverageReturn           | 1        |
# | AverageDiscountedReturn | 0.94721  |
# | TDError^2               | 0.002436 |
# --------------------------------------
# ----------------------------------------
# | Iteration               | 85         |
# | Steps                   | 85999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 12034      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94629    |
# | TDError^2               | 0.00097474 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 86         |
# | Steps                   | 86999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 12194      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.9491     |
# | TDError^2               | 0.00081182 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 87        |
# | Steps                   | 87999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 12354     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94531   |
# | TDError^2               | 0.0024628 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 88        |
# | Steps                   | 88999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 12500     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0012447 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 89        |
# | Steps                   | 89999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 12654     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0018051 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 90        |
# | Steps                   | 90999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 12813     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0014287 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 91        |
# | Steps                   | 91999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 12973     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.9491    |
# | TDError^2               | 0.0019471 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 92        |
# | Steps                   | 92999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 13130     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.94063   |
# | TDError^2               | 0.0011469 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 93         |
# | Steps                   | 93999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 13289      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.9491     |
# | TDError^2               | 0.00064784 |
# ----------------------------------------
# ----------------------------------------
# | Iteration               | 94         |
# | Steps                   | 94999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 13406      |
# | AverageReturn           | 0.7        |
# | AverageDiscountedReturn | 0.56744    |
# | TDError^2               | 0.00081181 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 95        |
# | Steps                   | 95999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 13503     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0021428 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 96         |
# | Steps                   | 96999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 13662      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.94345    |
# | TDError^2               | 0.00083299 |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 97        |
# | Steps                   | 97999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 13818     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.93883   |
# | TDError^2               | 0.0018878 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 98        |
# | Steps                   | 98999     |
# | Epsilon                 | 0.05      |
# | Episodes                | 13976     |
# | AverageReturn           | 1         |
# | AverageDiscountedReturn | 0.95099   |
# | TDError^2               | 0.0022941 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 99         |
# | Steps                   | 99999      |
# | Epsilon                 | 0.05       |
# | Episodes                | 14136      |
# | AverageReturn           | 1          |
# | AverageDiscountedReturn | 0.95004    |
# | TDError^2               | 0.00097164 |
# ----------------------------------------

# %%
# visualize learned policy
dqn_gridworld.test(epsilon=0.0)
# Out:
# 'NN_linear' object has no attribute 'set_params'
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Right)
# SFFF
# FFFH
# FFFF
# HFFG
#   (Down)
# SFFF
# FFFH
# FFFF
# HFFG
# Done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a2aac5f29ef0> in <module>()
#       1 # visualize learned policy
# ----> 2 dqn_gridworld.test(epsilon=0.0)
#
# <ipython-input-3-25f6cb3d3d33> in test(self, epsilon)
#     201                 obs = self._env.reset()
#     202                 print('Done!')
# --> 203                 time.sleep(1)
#     204             else:
#     205                 obs = obs_prime
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# ## 4. Test algorithm on Pong
# Now we can train for longer on a substantially more complex environment: Pong from the Atari suite. To speed up training, instead of playing from pixels we will be playing directly from the ram state.

# %%
env = EpisodicLifeEnv(NoopResetEnv(gym.make('Pong-ram-v0')))
log_dir = "data/local/dqn_pong"

logger.session(log_dir).__enter__()
env.seed(42)

# Initialize the replay buffer that we will use.
replay_buffer = ReplayBuffer(max_size=10000)

# Initialize DQN training procedure.
dqn_pong = DQN(
    env=env,
    obs_dim=env.observation_space.shape[0],
    act_dim=env.action_space.n,
    NN=NN,
    obs_preprocessor=preprocess_obs_ram,
    replay_buffer=replay_buffer,
    opt_batch_size=64,
    # DQN gamma parameter
    discount=0.99,
    # Training procedure length
    initial_step=1000000,
    max_steps=10000000,
    learning_start_itr=100000,
    # Frequency of copying the actual Q to the target Q
    target_q_update_freq=1000,
    # Frequency of updating the Q-value function
    train_q_freq=4,
    # Exploration parameters
    initial_eps=1.0,
    final_eps=0.05,
    fraction_eps=0.1,
    # Logging
    log_freq=10000,
    render=False,
)
# Out:
# [2018-04-04 14:44:05,649] Making new env: Pong-ram-v0

# %%
dqn_pong.train()
# Out:
# --------------------------------------
# | Iteration               | 0        |
# | Steps                   | 1.01e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 8        |
# | AverageReturn           | -20.625  |
# | AverageDiscountedReturn | -1.2601  |
# | TDError^2               | 0.012777 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 1         |
# | Steps                   | 1.02e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 16        |
# | AverageReturn           | -20.6     |
# | AverageDiscountedReturn | -1.0162   |
# | TDError^2               | 0.0055535 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 2         |
# | Steps                   | 1.03e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 25        |
# | AverageReturn           | -20.6     |
# | AverageDiscountedReturn | -0.89998  |
# | TDError^2               | 0.0031974 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 3         |
# | Steps                   | 1.04e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 34        |
# | AverageReturn           | -20.7     |
# | AverageDiscountedReturn | -1.0879   |
# | TDError^2               | 0.0031241 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 4         |
# | Steps                   | 1.05e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 43        |
# | AverageReturn           | -20.8     |
# | AverageDiscountedReturn | -1.1397   |
# | TDError^2               | 0.0030659 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 5         |
# | Steps                   | 1.06e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 52        |
# | AverageReturn           | -20.6     |
# | AverageDiscountedReturn | -1.1386   |
# | TDError^2               | 0.0037911 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 6         |
# | Steps                   | 1.07e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 60        |
# | AverageReturn           | -20.4     |
# | AverageDiscountedReturn | -1.0033   |
# | TDError^2               | 0.0060967 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 7         |
# | Steps                   | 1.08e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 68        |
# | AverageReturn           | -19.9     |
# | AverageDiscountedReturn | -0.87895  |
# | TDError^2               | 0.0050922 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 8         |
# | Steps                   | 1.09e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 75        |
# | AverageReturn           | -19.5     |
# | AverageDiscountedReturn | -0.85976  |
# | TDError^2               | 0.0096546 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 9         |
# | Steps                   | 1.1e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 82        |
# | AverageReturn           | -19.4     |
# | AverageDiscountedReturn | -0.84192  |
# | TDError^2               | 0.0071927 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 10       |
# | Steps                   | 1.11e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 88       |
# | AverageReturn           | -18.7    |
# | AverageDiscountedReturn | -0.92379 |
# | TDError^2               | 0.011626 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 11       |
# | Steps                   | 1.12e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 95       |
# | AverageReturn           | -18.5    |
# | AverageDiscountedReturn | -0.71899 |
# | TDError^2               | 0.010229 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 12        |
# | Steps                   | 1.13e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 102       |
# | AverageReturn           | -19.3     |
# | AverageDiscountedReturn | -0.97823  |
# | TDError^2               | 0.0069402 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 13        |
# | Steps                   | 1.14e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 109       |
# | AverageReturn           | -19.4     |
# | AverageDiscountedReturn | -0.67714  |
# | TDError^2               | 0.0088905 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 14       |
# | Steps                   | 1.15e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 116      |
# | AverageReturn           | -19.1    |
# | AverageDiscountedReturn | -0.68441 |
# | TDError^2               | 0.011809 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 15        |
# | Steps                   | 1.16e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 122       |
# | AverageReturn           | -18.9     |
# | AverageDiscountedReturn | -0.77924  |
# | TDError^2               | 0.0072795 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 16        |
# | Steps                   | 1.17e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 129       |
# | AverageReturn           | -18       |
# | AverageDiscountedReturn | -0.8322   |
# | TDError^2               | 0.0076461 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 17       |
# | Steps                   | 1.18e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 135      |
# | AverageReturn           | -17.6    |
# | AverageDiscountedReturn | -0.73139 |
# | TDError^2               | 0.00732  |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 18        |
# | Steps                   | 1.19e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 141       |
# | AverageReturn           | -18.3     |
# | AverageDiscountedReturn | -0.70076  |
# | TDError^2               | 0.0086128 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 19       |
# | Steps                   | 1.2e+06  |
# | Epsilon                 | 0.05     |
# | Episodes                | 146      |
# | AverageReturn           | -19.2    |
# | AverageDiscountedReturn | -0.72312 |
# | TDError^2               | 0.010472 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 20        |
# | Steps                   | 1.21e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 153       |
# | AverageReturn           | -18.5     |
# | AverageDiscountedReturn | -0.73529  |
# | TDError^2               | 0.0060059 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 21        |
# | Steps                   | 1.22e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 158       |
# | AverageReturn           | -19.7     |
# | AverageDiscountedReturn | -0.85265  |
# | TDError^2               | 0.0073072 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 22        |
# | Steps                   | 1.23e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 163       |
# | AverageReturn           | -19.6     |
# | AverageDiscountedReturn | -0.81502  |
# | TDError^2               | 0.0060199 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 23       |
# | Steps                   | 1.24e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 168      |
# | AverageReturn           | -19.6    |
# | AverageDiscountedReturn | -0.74965 |
# | TDError^2               | 0.013083 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 24        |
# | Steps                   | 1.25e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 174       |
# | AverageReturn           | -19.5     |
# | AverageDiscountedReturn | -0.66132  |
# | TDError^2               | 0.0055489 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 25        |
# | Steps                   | 1.26e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 179       |
# | AverageReturn           | -19.3     |
# | AverageDiscountedReturn | -0.75945  |
# | TDError^2               | 0.0059377 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 26        |
# | Steps                   | 1.27e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 184       |
# | AverageReturn           | -18.7     |
# | AverageDiscountedReturn | -0.6425   |
# | TDError^2               | 0.0038642 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 27        |
# | Steps                   | 1.28e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 188       |
# | AverageReturn           | -18.2     |
# | AverageDiscountedReturn | -0.5777   |
# | TDError^2               | 0.0090175 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 28        |
# | Steps                   | 1.29e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 193       |
# | AverageReturn           | -18.8     |
# | AverageDiscountedReturn | -0.67647  |
# | TDError^2               | 0.0054565 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 29        |
# | Steps                   | 1.3e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 197       |
# | AverageReturn           | -18.2     |
# | AverageDiscountedReturn | -0.6458   |
# | TDError^2               | 0.0080755 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 30        |
# | Steps                   | 1.31e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 201       |
# | AverageReturn           | -17.9     |
# | AverageDiscountedReturn | -0.4764   |
# | TDError^2               | 0.0073493 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 31        |
# | Steps                   | 1.32e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 205       |
# | AverageReturn           | -17.3     |
# | AverageDiscountedReturn | -0.43856  |
# | TDError^2               | 0.0042021 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 32       |
# | Steps                   | 1.33e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 208      |
# | AverageReturn           | -17.1    |
# | AverageDiscountedReturn | -0.2828  |
# | TDError^2               | 0.00496  |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 33        |
# | Steps                   | 1.34e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 213       |
# | AverageReturn           | -17.5     |
# | AverageDiscountedReturn | -0.38882  |
# | TDError^2               | 0.0069871 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 34        |
# | Steps                   | 1.35e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 216       |
# | AverageReturn           | -18.1     |
# | AverageDiscountedReturn | -0.3786   |
# | TDError^2               | 0.0057221 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 35        |
# | Steps                   | 1.36e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 220       |
# | AverageReturn           | -18.2     |
# | AverageDiscountedReturn | -0.45165  |
# | TDError^2               | 0.0065892 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 36        |
# | Steps                   | 1.37e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 223       |
# | AverageReturn           | -17.2     |
# | AverageDiscountedReturn | -0.56746  |
# | TDError^2               | 0.0050775 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 37        |
# | Steps                   | 1.38e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 226       |
# | AverageReturn           | -16.8     |
# | AverageDiscountedReturn | -0.68273  |
# | TDError^2               | 0.0039053 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 38        |
# | Steps                   | 1.39e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 229       |
# | AverageReturn           | -16.1     |
# | AverageDiscountedReturn | -0.68298  |
# | TDError^2               | 0.0043864 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 39        |
# | Steps                   | 1.4e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 233       |
# | AverageReturn           | -16.2     |
# | AverageDiscountedReturn | -0.63867  |
# | TDError^2               | 0.0040567 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 40        |
# | Steps                   | 1.41e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 236       |
# | AverageReturn           | -16.1     |
# | AverageDiscountedReturn | -0.4936   |
# | TDError^2               | 0.0060669 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 41        |
# | Steps                   | 1.42e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 240       |
# | AverageReturn           | -16.5     |
# | AverageDiscountedReturn | -0.52694  |
# | TDError^2               | 0.0046512 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 42        |
# | Steps                   | 1.43e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 243       |
# | AverageReturn           | -17       |
# | AverageDiscountedReturn | -0.41835  |
# | TDError^2               | 0.0040638 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 43       |
# | Steps                   | 1.44e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 247      |
# | AverageReturn           | -17.6    |
# | AverageDiscountedReturn | -0.38184 |
# | TDError^2               | 0.005781 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 44        |
# | Steps                   | 1.45e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 250       |
# | AverageReturn           | -17.5     |
# | AverageDiscountedReturn | -0.2561   |
# | TDError^2               | 0.0057485 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 45        |
# | Steps                   | 1.46e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 253       |
# | AverageReturn           | -16.6     |
# | AverageDiscountedReturn | -0.32287  |
# | TDError^2               | 0.0035646 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 46        |
# | Steps                   | 1.47e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 256       |
# | AverageReturn           | -16.4     |
# | AverageDiscountedReturn | -0.37512  |
# | TDError^2               | 0.0045451 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 47        |
# | Steps                   | 1.48e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 260       |
# | AverageReturn           | -16.8     |
# | AverageDiscountedReturn | -0.4683   |
# | TDError^2               | 0.0034533 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 48        |
# | Steps                   | 1.49e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 263       |
# | AverageReturn           | -17.3     |
# | AverageDiscountedReturn | -0.42745  |
# | TDError^2               | 0.0052171 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 49        |
# | Steps                   | 1.5e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 266       |
# | AverageReturn           | -16.3     |
# | AverageDiscountedReturn | -0.58126  |
# | TDError^2               | 0.0040383 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 50        |
# | Steps                   | 1.51e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 268       |
# | AverageReturn           | -16       |
# | AverageDiscountedReturn | -0.51994  |
# | TDError^2               | 0.0060711 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 51        |
# | Steps                   | 1.52e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 271       |
# | AverageReturn           | -14.8     |
# | AverageDiscountedReturn | -0.55653  |
# | TDError^2               | 0.0048281 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 52        |
# | Steps                   | 1.53e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 274       |
# | AverageReturn           | -15.5     |
# | AverageDiscountedReturn | -0.42909  |
# | TDError^2               | 0.0068031 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 53       |
# | Steps                   | 1.54e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 278      |
# | AverageReturn           | -17.4    |
# | AverageDiscountedReturn | -0.42012 |
# | TDError^2               | 0.004937 |
# --------------------------------------
# --------------------------------------
# | Iteration               | 54       |
# | Steps                   | 1.55e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 281      |
# | AverageReturn           | -17.3    |
# | AverageDiscountedReturn | -0.56593 |
# | TDError^2               | 0.004583 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 55        |
# | Steps                   | 1.56e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 284       |
# | AverageReturn           | -16.9     |
# | AverageDiscountedReturn | -0.57741  |
# | TDError^2               | 0.0056538 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 56        |
# | Steps                   | 1.57e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 287       |
# | AverageReturn           | -16.7     |
# | AverageDiscountedReturn | -0.52744  |
# | TDError^2               | 0.0042925 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 57        |
# | Steps                   | 1.58e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 290       |
# | AverageReturn           | -16.8     |
# | AverageDiscountedReturn | -0.40693  |
# | TDError^2               | 0.0064136 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 58        |
# | Steps                   | 1.59e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 294       |
# | AverageReturn           | -17.9     |
# | AverageDiscountedReturn | -0.42284  |
# | TDError^2               | 0.0046409 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 59        |
# | Steps                   | 1.6e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 297       |
# | AverageReturn           | -17.1     |
# | AverageDiscountedReturn | -0.44634  |
# | TDError^2               | 0.0037985 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 60        |
# | Steps                   | 1.61e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 300       |
# | AverageReturn           | -16.7     |
# | AverageDiscountedReturn | -0.49278  |
# | TDError^2               | 0.0037292 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 61        |
# | Steps                   | 1.62e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 303       |
# | AverageReturn           | -16.9     |
# | AverageDiscountedReturn | -0.53473  |
# | TDError^2               | 0.0050576 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 62        |
# | Steps                   | 1.63e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 305       |
# | AverageReturn           | -16.6     |
# | AverageDiscountedReturn | -0.37279  |
# | TDError^2               | 0.0042262 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 63       |
# | Steps                   | 1.64e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 308      |
# | AverageReturn           | -16.6    |
# | AverageDiscountedReturn | -0.41428 |
# | TDError^2               | 0.002498 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 64        |
# | Steps                   | 1.65e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 311       |
# | AverageReturn           | -17.2     |
# | AverageDiscountedReturn | -0.45274  |
# | TDError^2               | 0.0027465 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 65        |
# | Steps                   | 1.66e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 314       |
# | AverageReturn           | -16.9     |
# | AverageDiscountedReturn | -0.56369  |
# | TDError^2               | 0.0040285 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 66        |
# | Steps                   | 1.67e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 318       |
# | AverageReturn           | -17.5     |
# | AverageDiscountedReturn | -0.64559  |
# | TDError^2               | 0.0087548 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 67       |
# | Steps                   | 1.68e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 320      |
# | AverageReturn           | -16.4    |
# | AverageDiscountedReturn | -0.56055 |
# | TDError^2               | 0.004674 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 68        |
# | Steps                   | 1.69e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 323       |
# | AverageReturn           | -16.2     |
# | AverageDiscountedReturn | -0.474    |
# | TDError^2               | 0.0076628 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 69        |
# | Steps                   | 1.7e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 326       |
# | AverageReturn           | -16.6     |
# | AverageDiscountedReturn | -0.49243  |
# | TDError^2               | 0.0041593 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 70        |
# | Steps                   | 1.71e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 328       |
# | AverageReturn           | -16.4     |
# | AverageDiscountedReturn | -0.41959  |
# | TDError^2               | 0.0052766 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 71       |
# | Steps                   | 1.72e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 332      |
# | AverageReturn           | -17      |
# | AverageDiscountedReturn | -0.41618 |
# | TDError^2               | 0.009076 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 72        |
# | Steps                   | 1.73e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 334       |
# | AverageReturn           | -17       |
# | AverageDiscountedReturn | -0.40386  |
# | TDError^2               | 0.0036957 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 73        |
# | Steps                   | 1.74e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 336       |
# | AverageReturn           | -15.1     |
# | AverageDiscountedReturn | -0.29882  |
# | TDError^2               | 0.0046504 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 74       |
# | Steps                   | 1.75e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 338      |
# | AverageReturn           | -15.1    |
# | AverageDiscountedReturn | -0.25164 |
# | TDError^2               | 0.004112 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 75        |
# | Steps                   | 1.76e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 341       |
# | AverageReturn           | -14.1     |
# | AverageDiscountedReturn | -0.22728  |
# | TDError^2               | 0.0038566 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 76        |
# | Steps                   | 1.77e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 343       |
# | AverageReturn           | -13.6     |
# | AverageDiscountedReturn | -0.15215  |
# | TDError^2               | 0.0040589 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 77        |
# | Steps                   | 1.78e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 345       |
# | AverageReturn           | -13.6     |
# | AverageDiscountedReturn | -0.11622  |
# | TDError^2               | 0.0039948 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 78        |
# | Steps                   | 1.79e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 348       |
# | AverageReturn           | -13.5     |
# | AverageDiscountedReturn | -0.12497  |
# | TDError^2               | 0.0048001 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 79        |
# | Steps                   | 1.8e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 350       |
# | AverageReturn           | -13.2     |
# | AverageDiscountedReturn | -0.13832  |
# | TDError^2               | 0.0040778 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 80        |
# | Steps                   | 1.81e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 352       |
# | AverageReturn           | -13.3     |
# | AverageDiscountedReturn | -0.16655  |
# | TDError^2               | 0.0064539 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 81        |
# | Steps                   | 1.82e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 355       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.27729  |
# | TDError^2               | 0.0056699 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 82        |
# | Steps                   | 1.83e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 358       |
# | AverageReturn           | -11.8     |
# | AverageDiscountedReturn | -0.22241  |
# | TDError^2               | 0.0054238 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 83        |
# | Steps                   | 1.84e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 360       |
# | AverageReturn           | -11.9     |
# | AverageDiscountedReturn | -0.22433  |
# | TDError^2               | 0.0071678 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 84        |
# | Steps                   | 1.85e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 363       |
# | AverageReturn           | -12.8     |
# | AverageDiscountedReturn | -0.10797  |
# | TDError^2               | 0.0053511 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 85        |
# | Steps                   | 1.86e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 365       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.12946  |
# | TDError^2               | 0.0052351 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 86        |
# | Steps                   | 1.87e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 367       |
# | AverageReturn           | -13.5     |
# | AverageDiscountedReturn | -0.16557  |
# | TDError^2               | 0.0045424 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 87        |
# | Steps                   | 1.88e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 370       |
# | AverageReturn           | -13.1     |
# | AverageDiscountedReturn | -0.23463  |
# | TDError^2               | 0.0039234 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 88        |
# | Steps                   | 1.89e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 373       |
# | AverageReturn           | -12.8     |
# | AverageDiscountedReturn | -0.20808  |
# | TDError^2               | 0.0042422 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 89        |
# | Steps                   | 1.9e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 375       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.17755  |
# | TDError^2               | 0.0052423 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 90        |
# | Steps                   | 1.91e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 377       |
# | AverageReturn           | -12.7     |
# | AverageDiscountedReturn | -0.17079  |
# | TDError^2               | 0.0056109 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 91        |
# | Steps                   | 1.92e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 379       |
# | AverageReturn           | -12.2     |
# | AverageDiscountedReturn | -0.17932  |
# | TDError^2               | 0.0038656 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 92        |
# | Steps                   | 1.93e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 381       |
# | AverageReturn           | -11.6     |
# | AverageDiscountedReturn | -0.023719 |
# | TDError^2               | 0.0070478 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 93        |
# | Steps                   | 1.94e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 384       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.12623  |
# | TDError^2               | 0.0041187 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 94        |
# | Steps                   | 1.95e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 386       |
# | AverageReturn           | -12.4     |
# | AverageDiscountedReturn | -0.14093  |
# | TDError^2               | 0.0035315 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 95        |
# | Steps                   | 1.96e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 389       |
# | AverageReturn           | -13.6     |
# | AverageDiscountedReturn | -0.24565  |
# | TDError^2               | 0.0034692 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 96        |
# | Steps                   | 1.97e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 391       |
# | AverageReturn           | -13.9     |
# | AverageDiscountedReturn | -0.37186  |
# | TDError^2               | 0.0038077 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 97       |
# | Steps                   | 1.98e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 394      |
# | AverageReturn           | -14.1    |
# | AverageDiscountedReturn | -0.39177 |
# | TDError^2               | 0.004127 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 98        |
# | Steps                   | 1.99e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 396       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.3143   |
# | TDError^2               | 0.0032977 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 99        |
# | Steps                   | 2e+06     |
# | Epsilon                 | 0.05      |
# | Episodes                | 398       |
# | AverageReturn           | -12.5     |
# | AverageDiscountedReturn | -0.23056  |
# | TDError^2               | 0.0043687 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 100       |
# | Steps                   | 2.01e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 401       |
# | AverageReturn           | -11.9     |
# | AverageDiscountedReturn | -0.10078  |
# | TDError^2               | 0.0039139 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 101       |
# | Steps                   | 2.02e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 403       |
# | AverageReturn           | -11.4     |
# | AverageDiscountedReturn | -0.1037   |
# | TDError^2               | 0.0038615 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 102       |
# | Steps                   | 2.03e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 406       |
# | AverageReturn           | -13.1     |
# | AverageDiscountedReturn | -0.19497  |
# | TDError^2               | 0.0033764 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 103       |
# | Steps                   | 2.04e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 408       |
# | AverageReturn           | -12.4     |
# | AverageDiscountedReturn | -0.27991  |
# | TDError^2               | 0.0042614 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 104       |
# | Steps                   | 2.05e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 410       |
# | AverageReturn           | -11.8     |
# | AverageDiscountedReturn | -0.28336  |
# | TDError^2               | 0.0045685 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 105      |
# | Steps                   | 2.06e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 413      |
# | AverageReturn           | -12.5    |
# | AverageDiscountedReturn | -0.31989 |
# | TDError^2               | 0.003333 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 106       |
# | Steps                   | 2.07e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 415       |
# | AverageReturn           | -11       |
# | AverageDiscountedReturn | -0.33403  |
# | TDError^2               | 0.0031976 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 107       |
# | Steps                   | 2.08e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 417       |
# | AverageReturn           | -11.5     |
# | AverageDiscountedReturn | -0.21033  |
# | TDError^2               | 0.0048821 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 108       |
# | Steps                   | 2.09e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 420       |
# | AverageReturn           | -12.5     |
# | AverageDiscountedReturn | -0.16259  |
# | TDError^2               | 0.0075394 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 109       |
# | Steps                   | 2.1e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 424       |
# | AverageReturn           | -13.4     |
# | AverageDiscountedReturn | -0.064622 |
# | TDError^2               | 0.0055909 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 110       |
# | Steps                   | 2.11e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 426       |
# | AverageReturn           | -13.9     |
# | AverageDiscountedReturn | -0.045282 |
# | TDError^2               | 0.0047713 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 111       |
# | Steps                   | 2.12e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 428       |
# | AverageReturn           | -14.7     |
# | AverageDiscountedReturn | -0.13444  |
# | TDError^2               | 0.0043663 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 112       |
# | Steps                   | 2.13e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 431       |
# | AverageReturn           | -14.2     |
# | AverageDiscountedReturn | -0.10898  |
# | TDError^2               | 0.0041865 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 113       |
# | Steps                   | 2.14e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 433       |
# | AverageReturn           | -13.7     |
# | AverageDiscountedReturn | -0.10519  |
# | TDError^2               | 0.0031112 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 114       |
# | Steps                   | 2.15e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 436       |
# | AverageReturn           | -13.5     |
# | AverageDiscountedReturn | -0.11143  |
# | TDError^2               | 0.0038334 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 115       |
# | Steps                   | 2.16e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 439       |
# | AverageReturn           | -13.7     |
# | AverageDiscountedReturn | -0.11213  |
# | TDError^2               | 0.0033378 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 116       |
# | Steps                   | 2.17e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 441       |
# | AverageReturn           | -12.8     |
# | AverageDiscountedReturn | -0.094429 |
# | TDError^2               | 0.0061616 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 117       |
# | Steps                   | 2.18e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 443       |
# | AverageReturn           | -12.2     |
# | AverageDiscountedReturn | -0.081654 |
# | TDError^2               | 0.0029923 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 118       |
# | Steps                   | 2.19e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 445       |
# | AverageReturn           | -12.8     |
# | AverageDiscountedReturn | -0.21856  |
# | TDError^2               | 0.0073537 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 119       |
# | Steps                   | 2.2e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 448       |
# | AverageReturn           | -12.2     |
# | AverageDiscountedReturn | -0.18906  |
# | TDError^2               | 0.0049156 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 120       |
# | Steps                   | 2.21e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 450       |
# | AverageReturn           | -12.8     |
# | AverageDiscountedReturn | -0.10529  |
# | TDError^2               | 0.0058607 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 121      |
# | Steps                   | 2.22e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 453      |
# | AverageReturn           | -12.8    |
# | AverageDiscountedReturn | -0.11721 |
# | TDError^2               | 0.003674 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 122       |
# | Steps                   | 2.23e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 455       |
# | AverageReturn           | -13.4     |
# | AverageDiscountedReturn | -0.16251  |
# | TDError^2               | 0.0054665 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 123       |
# | Steps                   | 2.24e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 457       |
# | AverageReturn           | -13       |
# | AverageDiscountedReturn | -0.15096  |
# | TDError^2               | 0.0036753 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 124       |
# | Steps                   | 2.25e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 459       |
# | AverageReturn           | -12.3     |
# | AverageDiscountedReturn | -0.13063  |
# | TDError^2               | 0.0049211 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 125      |
# | Steps                   | 2.26e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 462      |
# | AverageReturn           | -12.4    |
# | AverageDiscountedReturn | -0.34599 |
# | TDError^2               | 0.004047 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 126       |
# | Steps                   | 2.27e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 465       |
# | AverageReturn           | -11.6     |
# | AverageDiscountedReturn | -0.40027  |
# | TDError^2               | 0.0034872 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 127       |
# | Steps                   | 2.28e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 468       |
# | AverageReturn           | -12.7     |
# | AverageDiscountedReturn | -0.40264  |
# | TDError^2               | 0.0045058 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 128       |
# | Steps                   | 2.29e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 470       |
# | AverageReturn           | -13.9     |
# | AverageDiscountedReturn | -0.40962  |
# | TDError^2               | 0.0054276 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 129       |
# | Steps                   | 2.3e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 472       |
# | AverageReturn           | -13.1     |
# | AverageDiscountedReturn | -0.36117  |
# | TDError^2               | 0.0031993 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 130       |
# | Steps                   | 2.31e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 475       |
# | AverageReturn           | -13.9     |
# | AverageDiscountedReturn | -0.34967  |
# | TDError^2               | 0.0045932 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 131       |
# | Steps                   | 2.32e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 478       |
# | AverageReturn           | -13.5     |
# | AverageDiscountedReturn | -0.40806  |
# | TDError^2               | 0.0050253 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 132       |
# | Steps                   | 2.33e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 481       |
# | AverageReturn           | -14.6     |
# | AverageDiscountedReturn | -0.25699  |
# | TDError^2               | 0.0034922 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 133       |
# | Steps                   | 2.34e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 483       |
# | AverageReturn           | -15.5     |
# | AverageDiscountedReturn | -0.31507  |
# ...
# | Episodes                | 692       |
# | AverageReturn           | -11.5     |
# | AverageDiscountedReturn | -0.035856 |
# | TDError^2               | 0.0034223 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 222       |
# | Steps                   | 3.23e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 694       |
# | AverageReturn           | -11.3     |
# | AverageDiscountedReturn | -0.072301 |
# | TDError^2               | 0.0029997 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 223       |
# | Steps                   | 3.24e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 696       |
# | AverageReturn           | -11.8     |
# | AverageDiscountedReturn | -0.11953  |
# | TDError^2               | 0.0025383 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 224       |
# | Steps                   | 3.25e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 698       |
# | AverageReturn           | -11       |
# | AverageDiscountedReturn | -0.14504  |
# | TDError^2               | 0.0039821 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 225       |
# | Steps                   | 3.26e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 700       |
# | AverageReturn           | -9.5      |
# | AverageDiscountedReturn | -0.052777 |
# | TDError^2               | 0.0028811 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 226       |
# | Steps                   | 3.27e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 703       |
# | AverageReturn           | -9.7      |
# | AverageDiscountedReturn | -0.099947 |
# | TDError^2               | 0.0038011 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 227       |
# | Steps                   | 3.28e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 705       |
# | AverageReturn           | -10.5     |
# | AverageDiscountedReturn | -0.12357  |
# | TDError^2               | 0.0024133 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 228       |
# | Steps                   | 3.29e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 707       |
# | AverageReturn           | -11.1     |
# | AverageDiscountedReturn | -0.14224  |
# | TDError^2               | 0.0026592 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 229       |
# | Steps                   | 3.3e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 709       |
# | AverageReturn           | -10.4     |
# | AverageDiscountedReturn | -0.20074  |
# | TDError^2               | 0.0028279 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 230       |
# | Steps                   | 3.31e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 711       |
# | AverageReturn           | -10.8     |
# | AverageDiscountedReturn | -0.22647  |
# | TDError^2               | 0.0029333 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 231       |
# | Steps                   | 3.32e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 713       |
# | AverageReturn           | -9.3      |
# | AverageDiscountedReturn | -0.18     |
# | TDError^2               | 0.0041246 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 232       |
# | Steps                   | 3.33e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 715       |
# | AverageReturn           | -8.8      |
# | AverageDiscountedReturn | -0.097516 |
# | TDError^2               | 0.0033448 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 233       |
# | Steps                   | 3.34e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 717       |
# | AverageReturn           | -8.4      |
# | AverageDiscountedReturn | -0.13055  |
# | TDError^2               | 0.0032026 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 234       |
# | Steps                   | 3.35e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 719       |
# | AverageReturn           | -9.5      |
# | AverageDiscountedReturn | -0.047255 |
# | TDError^2               | 0.0041283 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 235       |
# | Steps                   | 3.36e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 722       |
# | AverageReturn           | -11.6     |
# | AverageDiscountedReturn | -0.035178 |
# | TDError^2               | 0.0036418 |
# ---------------------------------------
# ----------------------------------------
# | Iteration               | 236        |
# | Steps                   | 3.37e+06   |
# | Epsilon                 | 0.05       |
# | Episodes                | 724        |
# | AverageReturn           | -13        |
# | AverageDiscountedReturn | 0.00078874 |
# | TDError^2               | 0.0034422  |
# ----------------------------------------
# ---------------------------------------
# | Iteration               | 237       |
# | Steps                   | 3.38e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 727       |
# | AverageReturn           | -13       |
# | AverageDiscountedReturn | 0.024181  |
# | TDError^2               | 0.0045017 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 238       |
# | Steps                   | 3.39e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 729       |
# | AverageReturn           | -13.6     |
# | AverageDiscountedReturn | -0.04781  |
# | TDError^2               | 0.0038491 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 239       |
# | Steps                   | 3.4e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 732       |
# | AverageReturn           | -12.6     |
# | AverageDiscountedReturn | -0.027076 |
# | TDError^2               | 0.0032305 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 240       |
# | Steps                   | 3.41e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 734       |
# | AverageReturn           | -12.5     |
# | AverageDiscountedReturn | -0.17582  |
# | TDError^2               | 0.0035709 |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 241      |
# | Steps                   | 3.42e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 737      |
# | AverageReturn           | -12.8    |
# | AverageDiscountedReturn | -0.18904 |
# | TDError^2               | 0.004896 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 242       |
# | Steps                   | 3.43e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 740       |
# | AverageReturn           | -11.9     |
# | AverageDiscountedReturn | -0.15429  |
# | TDError^2               | 0.0055325 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 243       |
# | Steps                   | 3.44e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 742       |
# | AverageReturn           | -12.2     |
# | AverageDiscountedReturn | -0.21125  |
# | TDError^2               | 0.0044425 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 244       |
# | Steps                   | 3.45e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 745       |
# | AverageReturn           | -11.6     |
# | AverageDiscountedReturn | -0.05218  |
# | TDError^2               | 0.0053617 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 245       |
# | Steps                   | 3.46e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 747       |
# | AverageReturn           | -12.3     |
# | AverageDiscountedReturn | -0.16077  |
# | TDError^2               | 0.0039807 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 246       |
# | Steps                   | 3.47e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 749       |
# | AverageReturn           | -12.7     |
# | AverageDiscountedReturn | -0.097978 |
# | TDError^2               | 0.0050775 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 247       |
# | Steps                   | 3.48e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 752       |
# | AverageReturn           | -12.3     |
# | AverageDiscountedReturn | -0.073083 |
# | TDError^2               | 0.0027789 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 248       |
# | Steps                   | 3.49e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 754       |
# | AverageReturn           | -13       |
# | AverageDiscountedReturn | -0.18109  |
# | TDError^2               | 0.0040906 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 249       |
# | Steps                   | 3.5e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 757       |
# | AverageReturn           | -11.9     |
# | AverageDiscountedReturn | -0.10748  |
# | TDError^2               | 0.0027841 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 250       |
# | Steps                   | 3.51e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 759       |
# | AverageReturn           | -12.1     |
# | AverageDiscountedReturn | -0.11559  |
# | TDError^2               | 0.0032441 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 251       |
# | Steps                   | 3.52e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 761       |
# | AverageReturn           | -11.4     |
# | AverageDiscountedReturn | -0.17655  |
# | TDError^2               | 0.0048814 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 252       |
# | Steps                   | 3.53e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 764       |
# | AverageReturn           | -11.1     |
# | AverageDiscountedReturn | -0.14015  |
# | TDError^2               | 0.0039623 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 253       |
# | Steps                   | 3.54e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 766       |
# | AverageReturn           | -10.7     |
# | AverageDiscountedReturn | -0.052675 |
# | TDError^2               | 0.0046997 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 254       |
# | Steps                   | 3.55e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 768       |
# | AverageReturn           | -10.2     |
# | AverageDiscountedReturn | -0.18675  |
# | TDError^2               | 0.0073559 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 255       |
# | Steps                   | 3.56e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 771       |
# | AverageReturn           | -10.5     |
# | AverageDiscountedReturn | -0.18333  |
# | TDError^2               | 0.0039746 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 256       |
# | Steps                   | 3.57e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 773       |
# | AverageReturn           | -10.4     |
# | AverageDiscountedReturn | -0.097727 |
# | TDError^2               | 0.004214  |
# ---------------------------------------
# --------------------------------------
# | Iteration               | 257      |
# | Steps                   | 3.58e+06 |
# | Epsilon                 | 0.05     |
# | Episodes                | 775      |
# | AverageReturn           | -11.1    |
# | AverageDiscountedReturn | -0.18669 |
# | TDError^2               | 0.004173 |
# --------------------------------------
# ---------------------------------------
# | Iteration               | 258       |
# | Steps                   | 3.59e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 778       |
# | AverageReturn           | -11.9     |
# | AverageDiscountedReturn | -0.077824 |
# | TDError^2               | 0.0055232 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 259       |
# | Steps                   | 3.6e+06   |
# | Epsilon                 | 0.05      |
# | Episodes                | 781       |
# | AverageReturn           | -11.7     |
# | AverageDiscountedReturn | -0.1244   |
# | TDError^2               | 0.0048925 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 260       |
# | Steps                   | 3.61e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 783       |
# | AverageReturn           | -11.6     |
# | AverageDiscountedReturn | -0.12191  |
# | TDError^2               | 0.0040928 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 261       |
# | Steps                   | 3.62e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 785       |
# | AverageReturn           | -11       |
# | AverageDiscountedReturn | -0.11931  |
# | TDError^2               | 0.0037065 |
# ---------------------------------------
# ---------------------------------------
# | Iteration               | 262       |
# | Steps                   | 3.63e+06  |
# | Epsilon                 | 0.05      |
# | Episodes                | 788       |
# | AverageReturn           | -11.2     |
# | AverageDiscountedReturn | -0.13814  |
# | TDError^2               | 0.0036596 |
# ---------------------------------------
# --------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-9-133223496ba4> in <module>()
# ----> 1 dqn_pong.train()
#
# <ipython-input-3-25f6cb3d3d33> in train(self)
#     172                 # Train Q value function with sampled data.
#     173                 td_squared_error = self.train_q(
# --> 174                     l_obs, l_act, l_rew, l_obs_prime, l_done)
#     175                 l_tq_squared_error.append(td_squared_error)
#     176
#
# <ipython-input-3-25f6cb3d3d33> in train_q(self, l_obs, l_act, l_rew, l_next_obs, l_done)
#     123
#     124         loss.backward()
# --> 125         self.optimizer.step()
#     126
#     127         return loss.data
#
# ~/anaconda2/envs/deeprlbootcamp/lib/python3.5/site-packages/torch/optim/adam.py in step(self, closure)
#      76                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#      77
# ---> 78                 p.data.addcdiv_(-step_size, exp_avg, denom)
#      79
#      80         return loss
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualization
# To visualize your learning curves, you can use the `viskit` tool by calling in a terminal:
# `python viskit/frontend.py path/to/log_dir`
# where `path/to/log_dir` is by default `data/local/exp_name`, where `exp_name` is `dqn_pong` in the case of pong for example.
# For this visualization to work you need to have the path to the homework directory to be added to your `$PYTHONPATH`. You should then see in your browser something like this:
# ![title](simpledqn/pong_learning.png)
