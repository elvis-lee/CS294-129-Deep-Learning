# %%
# As usual, a bit of setup

import numpy as np
import matplotlib.pyplot as plt
from deeplearning.classifiers.cnn import *
from deeplearning.data_utils import get_CIFAR10_data
from deeplearning.gradient_check import eval_numerical_gradient_array, eval_numerical_gradient
from deeplearning.layers import *
from deeplearning.fast_layers import *
from deeplearning.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()

# %%
# Train a really good model on CIFAR-10
from deeplearning.classifiers.convnet3 import *
model = HaoConvNet3(weight_scale=0.006, hidden_dim=512, reg=0.001, dropout=0.5)

solver = Solver(model, data,
                num_epochs= 20, batch_size=128,
                update_rule='sgd_momentum',
                lr_decay = 0.9,
                optim_config={
                  'learning_rate': 1e-1,
                },
                verbose=True, print_every=60)
solver.train()
# Out:
# (Iteration 1 / 7640) loss: 2.310786
# (Epoch 0 / 20) train acc: 0.134000; val_acc: 0.095000
# (Iteration 61 / 7640) loss: 1.815648
# (Iteration 121 / 7640) loss: 1.572199
# (Iteration 181 / 7640) loss: 1.564581
# (Iteration 241 / 7640) loss: 1.422925
# (Iteration 301 / 7640) loss: 1.503722
# (Iteration 361 / 7640) loss: 1.290935
# Time elapsed (hh:mm:ss.ms) 0:05:27.391163
# (Epoch 1 / 20) train acc: 0.590000; val_acc: 0.592000
# (Iteration 421 / 7640) loss: 1.428416
# (Iteration 481 / 7640) loss: 1.340301
# (Iteration 541 / 7640) loss: 1.290536
# (Iteration 601 / 7640) loss: 1.238062
# (Iteration 661 / 7640) loss: 1.257411
# (Iteration 721 / 7640) loss: 1.325192
# Time elapsed (hh:mm:ss.ms) 0:10:53.538427
# (Epoch 2 / 20) train acc: 0.668000; val_acc: 0.650000
# (Iteration 781 / 7640) loss: 1.332941
# (Iteration 841 / 7640) loss: 1.656996
# (Iteration 901 / 7640) loss: 1.260511
# (Iteration 961 / 7640) loss: 1.346538
# (Iteration 1021 / 7640) loss: 1.373721
# (Iteration 1081 / 7640) loss: 1.435311
# (Iteration 1141 / 7640) loss: 1.284684
# Time elapsed (hh:mm:ss.ms) 0:16:17.518813
# (Epoch 3 / 20) train acc: 0.730000; val_acc: 0.666000
# (Iteration 1201 / 7640) loss: 1.321302
# (Iteration 1261 / 7640) loss: 1.253079
# (Iteration 1321 / 7640) loss: 1.280611
# (Iteration 1381 / 7640) loss: 1.321609
# (Iteration 1441 / 7640) loss: 1.289208
# (Iteration 1501 / 7640) loss: 1.361339
# Time elapsed (hh:mm:ss.ms) 0:21:33.332163
# (Epoch 4 / 20) train acc: 0.746000; val_acc: 0.713000
# (Iteration 1561 / 7640) loss: 1.238871
# (Iteration 1621 / 7640) loss: 1.400950
# (Iteration 1681 / 7640) loss: 1.362165
# (Iteration 1741 / 7640) loss: 1.341608
# (Iteration 1801 / 7640) loss: 1.254429
# (Iteration 1861 / 7640) loss: 1.420802
# Time elapsed (hh:mm:ss.ms) 0:26:47.640788
# (Epoch 5 / 20) train acc: 0.764000; val_acc: 0.721000
# (Iteration 1921 / 7640) loss: 1.306316
# (Iteration 1981 / 7640) loss: 1.173940
# (Iteration 2041 / 7640) loss: 1.360477
# (Iteration 2101 / 7640) loss: 1.310018
# (Iteration 2161 / 7640) loss: 1.125857
# (Iteration 2221 / 7640) loss: 1.297841
# (Iteration 2281 / 7640) loss: 1.279069
# Time elapsed (hh:mm:ss.ms) 0:32:02.972159
# (Epoch 6 / 20) train acc: 0.793000; val_acc: 0.715000
# (Iteration 2341 / 7640) loss: 1.282871
# (Iteration 2401 / 7640) loss: 1.276271
# (Iteration 2461 / 7640) loss: 1.257442
# (Iteration 2521 / 7640) loss: 1.427592
# (Iteration 2581 / 7640) loss: 1.282089
# (Iteration 2641 / 7640) loss: 1.508653
# Time elapsed (hh:mm:ss.ms) 0:37:20.131111
# (Epoch 7 / 20) train acc: 0.785000; val_acc: 0.724000
# (Iteration 2701 / 7640) loss: 1.379636
# (Iteration 2761 / 7640) loss: 1.277278
# (Iteration 2821 / 7640) loss: 1.231889
# (Iteration 2881 / 7640) loss: 1.362542
# (Iteration 2941 / 7640) loss: 1.401994
# (Iteration 3001 / 7640) loss: 1.756030
# Time elapsed (hh:mm:ss.ms) 0:42:34.527443
# (Epoch 8 / 20) train acc: 0.810000; val_acc: 0.725000
# (Iteration 3061 / 7640) loss: 1.316290
# (Iteration 3121 / 7640) loss: 1.339670
# (Iteration 3181 / 7640) loss: 1.183848
# (Iteration 3241 / 7640) loss: 1.303097
# (Iteration 3301 / 7640) loss: 1.513351
# (Iteration 3361 / 7640) loss: 1.420383
# (Iteration 3421 / 7640) loss: 1.362651
# Time elapsed (hh:mm:ss.ms) 0:47:48.728893
# (Epoch 9 / 20) train acc: 0.830000; val_acc: 0.737000
# (Iteration 3481 / 7640) loss: 1.413637
# (Iteration 3541 / 7640) loss: 1.386966
# (Iteration 3601 / 7640) loss: 1.325264
# (Iteration 3661 / 7640) loss: 1.431478
# (Iteration 3721 / 7640) loss: 1.464583
# (Iteration 3781 / 7640) loss: 1.389889
# Time elapsed (hh:mm:ss.ms) 0:53:02.825530
# (Epoch 10 / 20) train acc: 0.826000; val_acc: 0.745000
# (Iteration 3841 / 7640) loss: 1.410786
# (Iteration 3901 / 7640) loss: 1.382274
# (Iteration 3961 / 7640) loss: 1.427209
# (Iteration 4021 / 7640) loss: 1.398204
# (Iteration 4081 / 7640) loss: 1.437008
# (Iteration 4141 / 7640) loss: 1.336387
# (Iteration 4201 / 7640) loss: 1.301572
# Time elapsed (hh:mm:ss.ms) 0:58:17.078056
# (Epoch 11 / 20) train acc: 0.831000; val_acc: 0.742000
# (Iteration 4261 / 7640) loss: 1.411023
# (Iteration 4321 / 7640) loss: 1.383462
# (Iteration 4381 / 7640) loss: 1.484975
# (Iteration 4441 / 7640) loss: 1.426893
# (Iteration 4501 / 7640) loss: 1.522027
# (Iteration 4561 / 7640) loss: 1.434549
# Time elapsed (hh:mm:ss.ms) 1:03:31.569401
# (Epoch 12 / 20) train acc: 0.825000; val_acc: 0.732000
# (Iteration 4621 / 7640) loss: 1.276888
# (Iteration 4681 / 7640) loss: 1.354196
# (Iteration 4741 / 7640) loss: 1.552397
# (Iteration 4801 / 7640) loss: 1.333650
# (Iteration 4861 / 7640) loss: 1.252602
# (Iteration 4921 / 7640) loss: 1.411979
# Time elapsed (hh:mm:ss.ms) 1:08:46.157109
# (Epoch 13 / 20) train acc: 0.851000; val_acc: 0.748000
# (Iteration 4981 / 7640) loss: 1.519020
# (Iteration 5041 / 7640) loss: 1.466344
# (Iteration 5101 / 7640) loss: 1.304842
# (Iteration 5161 / 7640) loss: 1.435245
# (Iteration 5221 / 7640) loss: 1.329492
# (Iteration 5281 / 7640) loss: 1.278091
# (Iteration 5341 / 7640) loss: 1.375628
# Time elapsed (hh:mm:ss.ms) 1:14:00.435579
# (Epoch 14 / 20) train acc: 0.861000; val_acc: 0.754000
# (Iteration 5401 / 7640) loss: 1.373547
# (Iteration 5461 / 7640) loss: 1.352884
# (Iteration 5521 / 7640) loss: 1.375367
# (Iteration 5581 / 7640) loss: 1.406949
# (Iteration 5641 / 7640) loss: 1.312323
# (Iteration 5701 / 7640) loss: 1.324141
# Time elapsed (hh:mm:ss.ms) 1:19:15.035705
# (Epoch 15 / 20) train acc: 0.861000; val_acc: 0.729000
# (Iteration 5761 / 7640) loss: 1.343892
# (Iteration 5821 / 7640) loss: 1.387940
# (Iteration 5881 / 7640) loss: 1.311487
# (Iteration 5941 / 7640) loss: 1.312515
# (Iteration 6001 / 7640) loss: 1.302735
# (Iteration 6061 / 7640) loss: 1.418739
# Time elapsed (hh:mm:ss.ms) 1:24:29.904607
# (Epoch 16 / 20) train acc: 0.850000; val_acc: 0.741000
# (Iteration 6121 / 7640) loss: 1.343370
# (Iteration 6181 / 7640) loss: 1.254883
# (Iteration 6241 / 7640) loss: 1.262980
# (Iteration 6301 / 7640) loss: 1.363003
# (Iteration 6361 / 7640) loss: 1.428969
# (Iteration 6421 / 7640) loss: 1.372178
# (Iteration 6481 / 7640) loss: 1.402344
# Time elapsed (hh:mm:ss.ms) 1:29:44.967515
# (Epoch 17 / 20) train acc: 0.882000; val_acc: 0.758000
# (Iteration 6541 / 7640) loss: 1.300389
# (Iteration 6601 / 7640) loss: 1.394205
# (Iteration 6661 / 7640) loss: 1.305315
# (Iteration 6721 / 7640) loss: 1.443355
# (Iteration 6781 / 7640) loss: 1.318377
# (Iteration 6841 / 7640) loss: 1.308008
# Time elapsed (hh:mm:ss.ms) 1:34:59.304478
# (Epoch 18 / 20) train acc: 0.890000; val_acc: 0.737000
# (Iteration 6901 / 7640) loss: 1.301752
# (Iteration 6961 / 7640) loss: 1.361930
# (Iteration 7021 / 7640) loss: 1.332300
# (Iteration 7081 / 7640) loss: 1.290362
# (Iteration 7141 / 7640) loss: 1.167695
# (Iteration 7201 / 7640) loss: 1.281044
# Time elapsed (hh:mm:ss.ms) 1:40:12.899934
# (Epoch 19 / 20) train acc: 0.862000; val_acc: 0.752000
# (Iteration 7261 / 7640) loss: 1.326602
# (Iteration 7321 / 7640) loss: 1.330910
# (Iteration 7381 / 7640) loss: 1.332500
# (Iteration 7441 / 7640) loss: 1.330349
# (Iteration 7501 / 7640) loss: 1.411296
# (Iteration 7561 / 7640) loss: 1.287696
# (Iteration 7621 / 7640) loss: 1.247811
# Time elapsed (hh:mm:ss.ms) 1:45:27.870436
# (Epoch 20 / 20) train acc: 0.876000; val_acc: 0.750000

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
test_acc = solver.check_accuracy(data['X_test'], data['y_test'])
print 'test acc: %f' % (test_acc)
# Out:
# test acc: 0.736000
